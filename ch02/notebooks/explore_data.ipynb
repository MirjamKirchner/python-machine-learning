# %%
import sys
import pandas as pd
import os
import seaborn as sns

# %%
sys.path.append("..\\..")

# %%
from config import PATH_TO_DATA, configure_plots
configure_plots()

# %%
ftraining_data = "raw_iris.data"
colnames = ["sepal_length_cm", "sepal_width_cm", "petal_length_cm", "petal_width_cm", "target"]

# %%
training_data = pd.read_csv(os.path.join(PATH_TO_DATA, ftraining_data), header=None, names=colnames)

# %%
training_data.head()
# Out:
#    sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0              5.1             3.5              1.4             0.2
# 1              4.9             3.0              1.4             0.2
# 2              4.7             3.2              1.3             0.2
# 3              4.6             3.1              1.5             0.2
# 4              5.0             3.6              1.4             0.2
#
#         target
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
g = sns.scatterplot(x="sepal_length_cm", y="petal_length_cm", hue="target", data=training_data)
g.set(title="The three classes cannot be separated perfectly by a linear decision boundary")
# Out:
# [Text(0.5, 1.0, 'The three classes cannot be separated perfectly by a linear decision boundary')]
